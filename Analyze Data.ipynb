# %%
import requests
import json
from tqdm import tqdm
from convokit import Corpus, User, Utterance

# %%
mh_corpus = Corpus(filename=download("subreddit-mentalhealth"))
mh_corpus.load_info('utterance',['parsed'])
# Out:
# Dataset already exists at /Users/Emilie/.convokit/downloads/subreddit-mentalhealth

# %%
#a = Corpus(filename=download("subreddit-Anxiety"))

# %%
e = Corpus(filename=download('subreddit-EatingDisorders'))
# Out:
# Downloading subreddit-EatingDisorders to /Users/Emilie/.convokit/downloads/subreddit-EatingDisorders
# Downloading subreddit-EatingDisorders from http://zissou.infosci.cornell.edu/convokit/datasets/subreddit-corpus/corpus-zipped/EarthPornErrors~-~Ebay_deals/EatingDisorders.corpus.zip (6.7MB)... Done

# %%
all_data = mh_corpus.merge(e)
# Out:
# {'subreddit': 'EatingDisorders',
#  'num_posts': 3457,
#  'num_comments': 18755,
#  'num_user': 4812}

# %%
#https://gist.github.com/xandaschofield/3c4070b2f232b185ce6a09e47b4e7473 

import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer as CV
import string

exclude = set(string.punctuation)


def basic_sanitize(in_string):
    '''Returns a very roughly sanitized version of the input string.'''
    return_string = ''.join([ch for ch in in_string if ord(ch) < 128 and ch not in exclude]).lower()
    return_string = ' '.join(return_string.split())
    return return_string

def bayes_compare_language(l1, l2, ngram=1, prior=.01, cv=None, sig_val=2.573):
    '''
    Arguments:
    - l1, l2; a list of strings from each language sample
    - ngram; an int describing up to what n gram you want to consider (1 is unigrams,
    2 is bigrams + unigrams, etc). Ignored if a custom CountVectorizer is passed.
    - prior; either a float describing a uniform prior, or a vector describing a prior
    over vocabulary items. If you're using a predefined vocabulary, make sure to specify that
    when you make your CountVectorizer object.
    - cv; a sklearn.feature_extraction.text.CountVectorizer object, if desired.
    Returns:
    - A list of length |Vocab| where each entry is a (n-gram, zscore) tuple.'''
    if cv is None and type(prior) is not float:
        print("If using a non-uniform prior:")
        print("Please also pass a count vectorizer with the vocabulary parameter set.")
        quit()
    l1 = [basic_sanitize(l) for l in l1]
    l2 = [basic_sanitize(l) for l in l2]
    if cv is None:
        cv = CV(decode_error = 'ignore', min_df = 10, max_df = .5, ngram_range=(1,ngram),
                binary = False,
                max_features = 15000)
    counts_mat = cv.fit_transform(l1+l2).toarray()
    # Now sum over languages...
    vocab_size = len(cv.vocabulary_)
    print("Vocab size is {}".format(vocab_size))
    if type(prior) is float:
        priors = np.array([prior for i in range(vocab_size)])
    else:
        priors = prior
    z_scores = np.empty(priors.shape[0])
    count_matrix = np.empty([2, vocab_size], dtype=np.float32)
    count_matrix[0, :] = np.sum(counts_mat[:len(l1), :], axis = 0)
    count_matrix[1, :] = np.sum(counts_mat[len(l1):, :], axis = 0)
    a0 = np.sum(priors)
    n1 = 1.*np.sum(count_matrix[0,:])
    n2 = 1.*np.sum(count_matrix[1,:])
    print("Comparing language...")
    for i in range(vocab_size):
        #compute delta
        term1 = np.log((count_matrix[0,i] + priors[i])/(n1 + a0 - count_matrix[0,i] - priors[i]))
        term2 = np.log((count_matrix[1,i] + priors[i])/(n2 + a0 - count_matrix[1,i] - priors[i]))        
        delta = term1 - term2
        #compute variance on delta
        var = 1./(count_matrix[0,i] + priors[i]) + 1./(count_matrix[1,i] + priors[i])
        #store final score
        z_scores[i] = delta/np.sqrt(var)
    index_to_term = {v: k for k, v in cv.vocabulary_.items()}
    sorted_indices = np.argsort(z_scores)
    return_list = [(index_to_term[i], z_scores[i]) for i in sorted_indices]
    
    x_vals = count_matrix.sum(axis=0)
    y_vals = z_scores
    sizes = abs(z_scores) * 2
    neg_color, pos_color, insig_color = ('orange', 'purple', 'grey')
    colors = []
    annots = []
    for i, y in enumerate(y_vals):
        if y > sig_val:
            colors.append(pos_color)
            annots.append(index_to_term[i])
        elif y < -sig_val:
            colors.append(neg_color)
            annots.append(index_to_term[i])
        else:
            colors.append(insig_color)
            annots.append(None)

    fig, ax = plt.subplots()
    ax.scatter(x_vals, y_vals, c=colors, s=sizes, linewidth=0)
    for i, annot in enumerate(annots):
        if annot is not None:
            ax.annotate(annot, (x_vals[i], y_vals[i]), color=colors[i], size=sizes[i])
    ax.set_xscale('log')
    
    plt.savefig('test.pdf')

# %%
from nltk.corpus import stopwords
stopwords  = stopwords.words('english')

def removeStopwords(wordlist, stopwords):
    return [w for w in wordlist if w not in stopwords]

def wordListToFreqDict(wordlist):
    wordfreq = [wordlist.count(p) for p in wordlist]
    return dict(list(zip(wordlist,wordfreq)))

# %%
mh_convos = [] 
for i in (list(mh_corpus.iter_conversations())):
    mh_convos.append((i.meta['title']))

mh_wordlist = [i.split() for i in mh_convos]
mh_clean_wordlist = removeStopwords(mh_wordlist, stopwords)

# %%
e_convos = [] 
for i in (list(e.iter_conversations())):
    e_convos.append((i.meta['title']))

e_wordlist = [i.split() for i in e_convos]
e_clean_wordlist = removeStopwords(e_wordlist, stopwords)

# %%
e_convos
# Out:
# ['GF has been having stomach problems recently, just yesterday admitted to me she was bulimic for 4yrs before we were together(x-post from r/health)',
#  'BED is destroying me.',
#  'People Say Stupid Things',
#  'Alcoholism + Eating Disorders = Drunkorexia?',
#  'Eating Disorders and Holiday Guilt',
#  'Help Me Help Make ED Treatment More Accessible to All Who Need It!',
#  "I don't know what it's considered but I don't want help with my ED.",
#  'New to /r/EatingDisorders. If anyone needs someone to listen, you can PM me.',
#  'First World Eating Disorder Problems',
#  'What does recovery look like for you?',
#  "I don't know what to do...",
#  "I don't know what to do",
#  'Eating Disorders and the Media: Anti-Airbrush Movement',
#  "I'm not sure if I have an eating disorder, some advice?",
#  'The long-term effects...',
#  "I don't know what to do",
#  'ED Sufferer seeks healthy ways to lose weight. Needs to stop the yo-yoing, any advice?',
#  "I've been having trouble eating for a little over a year.",
#  'Your opinion on my friend...',
#  "My girlfriend has an eating disorder and it's ruining our relationship.",
#  "I've always wondered about anorexics. Do you feel hunger and choose not to eat? Or is there no appetite at all?",
#  'Dating with an eating disorder',
#  'Bulimia and hair loss... What should I do?',
#  'Scumbag eating disorder',
#  'Misconceptions of Eating Disorders',
#  "I'm a college student writing a short story about a young woman with anorexia nervosa, and I want to make her as realistic and interesting as possible.",
#  'Insurance Companies to Provide Better Coverage for Eating Disorders',
#  'Orthorexia, the "fourth" eating disorder?',
#  'I think I might have an eating problem',
#  'Sporadic bulimia addiction',
#  'Binge Fool',
#  'Post Request: My girlfriend is a recovering bulimic, but still struggles with it. How can I help her?',
#  'Eating Disorder Orthorexia On The Rise. Orthorexia defined in comments.',
#  'Post Request: Seeking advice.',
#  'Post Request: Where do EDs start?',
#  'Post Request: How do I prevent myself from developing BN?',
#  "Post Request: I'm worried about my sister's eating",
#  'Post request: Anorexia?',
#  'Post request: How to help my friend/boss?',
#  "Post request: My accomplishments vs my sister's ED",
#  'Post Request: "Where do EDs start?" - The Follow-Up',
#  'Post request: How do you deal with triggering behavior from family?',
#  'Post Request: Eating Enough for Recovery?',
#  "Post Request: Request for help asking my girlfriend if she's struggling with an ED.",
#  'Post Request: I need help dealing with my feelings about food.',
#  'Post Request: Faking an eating disorder or real concern - long, sorry',
#  'Post Request: How do you deal with ED thoughts and impulses after recovery?',
#  "Post Request: How do I tell my family/friends I'm bulimic?",
#  'Post Request: Reasons to Recover',
#  'Post Request: Can someone help me?',
#  'Post Request: What to say, if anything, to ED friends when they say something self depreciating.',
#  'Post Request: How did you develop your ED? How has it impacted your life? What motivated you to recover?',
#  'Post Request: How do I tell my best friend how much I really do understand her eating disorder?',
#  "Post Request: Brother has EDNOS but I'm overweight. How can I help myself in a healthy way for both of us?",
#  "Article by Dr. Nuno: What others can learn from my daughter's eating disorder",
#  'Post Request: Birth control and weight gain',
#  'Post Request: Just want to say thank you',
#  "Post Request: I'm scared I may have anorexia.",
#  'Post Request: How do I deal with an unsupportive family?',
#  'Post Request: I think I might have an ED. Do I need to tell my husband?',
#  "Post request: What can I do for a bulimic flatmate who's moving out in one week?",
#  'Post request: Undiagnosed male bulimic, without reliable treatment',
#  "Post Request: I am struggling with AN &amp; BN and a history of self-harm. I am not yet under weight, and I fear that if I tell someone they'll laugh at me.",
#  'Post Request: Question about inpatient treatment for anorexia',
#  'Post Request: How do I find the best treatment centers in the U.S.?',
#  'Post Request: 15 years of ED after untreated AN, what can I do about it now?',
#  'Post Request: 15 years of ED after untreated AN, what can I do about it now?',
#  'Post Request: Starving self when mad, sad, or depressed. How can I overcome it?',
#  'Post Request: Recovering from BN and saliva glands are swelling a lot.',
#  "I just told my boyfriend and family that I've been bulimic for the last year -now what?",
#  'Binge eating: Patients struggle to break free when food takes control.',
#  "I think I might have a problem, and I don't know what to do. help",
#  'Recovery is hard',
#  'Is it common for lots of your organs to be in random pain if you have an eating disorder?',
#  'My 6 yr old son asked me today "Mommy, how come I never see you eat food?". Really?! I hate this disease. ',
#  'Any others dove into an ED by comments of how tiny you are? (Please dont hate..)',
#  'An Eating Disorder Which Turned Into More',
#  'Going Hungry: Writers on desire, self-denial, and overcoming anorexia. Edited by Kate Taylor. Book Review',
#  'The Anorexia Workbook: How to accept yourself, heal your suffering, and reclaim your life. Book Review',
#  'Demi Lovato discusses her ED in an MTV documentary',
#  'Picky Eating Disorder',
#  'Eating Disorders: Confronting Friends or Family',
#  'Penn &amp; Teller: Addiction (relevant)',
#  'Unbearable Lightness: A story of loss and gain. By Portia de Rossi: Actress from Arrested Development and Ally McBeal.  -Book Review',
#  'Have you heard of the online "thinspo" culture? Do social media perpetuate eating disorders?',
#  'Dying to be Thin: Understanding and defeating anorexia nervosa and bulimia.  Book Review',
#  'Help me - am I okay?',
#  'Empty: A story of anorexia. By Christie Pettit. -Book Review.',
#  'Poop question!/ Where is your kidney located exsatly',
#  'Life Without Ed: How One Woman Declared Independence from Her Eating Disorder. By Jenni Schaefer with Thom Rutledge. - Book Review',
#  'One Life: Hope, Healing and Inspiration on the Path to Recovery. By Naomi Feigenbaum. -Book Review\n',
#  'it is me? or do i think demi lavato is a phony person...',
#  ' Not sure what to do or think. Could use some help',
#  'Eating Disorders and the Fear of the Ordinary (Thought Catalog)',
#  'Do treatment teams just lie about bulimia and weight loss? [TW for not necessarily recovery-oriented]',
#  'ED and drug abuse',
#  'Recovery &amp; hormonal changes',
#  'Eating Disorders are Becoming Increasingly Prevalent Among Middle-aged Women',
#  'Eating Disorders and Comorbidity - Can Your Eating Disorder Clinic Cope with Dual-diagnosis Care?',
#  'Recovery from bulimia question',
#  'Does feeling abandoned by a parent make you more likely to have an eating disorder.',
#  'Stop weight yourself!',
#  '“Be Careful You Don’t Get Fat.”',
#  'T-shirt. So true. Possible TW. (crosspost /r/EDRecovery and WTF)',
#  'Not sure what to do about a reemerging ED?',
#  'How do I help a friend dealing with an ED?',
#  "I have to read Omnivore's Dilemma for a class and I'm worried it will be triggering.",
#  'What are your feeling towards seeking treatment for eating disorders?',
#  'Wasted: A Memoir of Anorexia and Bulimia. By Marya Hornbacher. --Book Review',
#  'Have any of you experienced hair loss? How long until my hair stops falling out?',
#  'disenchantED - living life with an eating disorder',
#  "I lose control when I'm alone",
#  "I can't shake it, everywhere I go, Mia follows.",
#  'Request: Hypnosis, yay or nay?',
#  'Request: How do I start eating again and not become nauseous or vomit? [emetophobia]',
#  'Request: How do I get my husband to be supportive and understanding?',
#  'Request: Help me help my girlfriend.',
#  'REQUEST: Any information comparing Anorexia Nervosa to Body Dysmorphia?',
#  'Request: When will my period come back?',
#  'Request: My friend is killing himself',
#  "Request: I'm an extremely picky eater and I can't help it",
#  "Request: Lost medical assistance. Don't know what to do",
#  'Request: Potential eating disorder, hostile to recovery',
#  "Request: Good friend is most likely slipping into an ED, and I'm not sure how to best support them or how serious it is",
#  'Request: Should I be concerned about my friend? She has a history of restrictive eating and is in mourning of her father.',
#  'Request: I am worried about my friend - what should I do?',
#  'Five Strategies for Managing Eating Disorder Thoughts',
#  'Request: People with eating disorders: what families and friends can realistically do to help you?',
#  "Request: recently noticing that my therapist who I'm seeing for anorexia is sickly thin looking",
#  "Request: I don't have an unhealthy relationship with food but have begun purging when I'm upset. Should I see a professional?",
#  'Success Story: BED recovery',
#  'Request: Mom micromanaging my what I eat',
#  "Request: What's wrong with me? Is it bulimia?",
#  'Request: Should I ask my guidance counselor?',
#  'Request: Personal and confidential information (concerns about housemate)',
#  'Request: Are my thoughts unhealthy? Scared that I might develop an eating disorder',
#  'Request: I need help, ED coming back',
#  'Request: Bikini Bartender Recovering from an Eating Disorder - Desperately Need Advice',
#  'Request: Bikini Bartender Recovering from an Eating Disorder - Desperately Need Advice',
#  'Request: I believe my sister is suffering from BED/EDNOS. How can I get her help?',
#  'Request: Had disordered eating for 8 years, recovered but now want to lose weight without slipping back into disordered thoughts',
#  'Request; want to lose weight but fear relapse',
#  'Request: BED Recovery and Substance Abuse - How do I fight two battles at once?',
#  'Request: Can you still have an ED if it looks nothing like the textbooks?',
#  'Request: My Eating Disorder Therapist Has An Eating Disorder',
#  'Research Article: Defining Purging Disorder in Practice',
#  "Request: How to eat regularly when I can't exercise due to physical limitation",
#  'Request: What to do after an argument with my bulimic girlfriend',
#  'Request: Sick but not "Sick"?',
#  'Request: I accidentally triggered my gf. How do I fix it and regain her trust and comfort?',
#  'Request: Relationship with exercise?',
#  'Request: What are some of the harmful side-effects that bulimia has on your body? Can I heal my body from these? PLEASE',
#  "Request: Counselor isn't offering much help with binging issue",
#  "Request: How do you know if you're dangerously underweight?",
#  'Request: How Can I Help My GF Realize That She Has Severe Body Dismorphia',
#  'Request: Anorexia vs. Anorexia Nervosa and what could trigger the first one',
#  'Request: Girlfriend developing anorexia',
#  'Request: My friends eating disorder',
#  'Request: Help managing Binge Eating',
#  'Request: GAD and possibly disordered eating',
#  'Request: dentist help',
#  'Request: How do I fix my water-drinking habits?',
#  'Request: Put on a lot of weight binging now starting to restrict',
#  'Request: Eating more than others',
#  'Request: Nausea and increasing fats',
#  'Request: What do you do when you find yourself tempted to relapse...?',
#  "Request: I am never hungry and when I am I feel the physical need to vomit after. What's wrong with me?",
#  'Request: Help with my ED (next steps)',
#  "Request: Just realizing I'm suffering from some kind of ED. How do I go about fixing it?",
#  'Request: Girlfriend too dependent for support',
#  'Request: When/how to trust intuitive eating?',
#  'Request: Low energy in early recovery',
#  'Request: Music to support a friend with ED',
#  '[Recovery] Food diary app, Discovery in Recovery',
#  '[Recovery] A food diary phone app for tracking recovery: Discovery in Recovery',
#  'Request: Recommendations for an ED-friendly cookbook?',
#  "Request: I can't tell if I am anorexic",
#  'Info: Center for Discovery Scholarship Offer',
#  "Request: Not sure if I'm ill/lazy/relapsing/something else...",
#  'Request: My Wife',
#  'Restrictive medical diet makes my binging worse. What can I do?',
#  'Request: Medication effecting appetite',
#  'Request: how to overcome Night Eating Syndrome (NES)',
#  'Research: Recruiting for a study',
#  "Request: Supporting a loved one who doesn't want help",
#  'Research: Desired resources for Depression/Mental health website.',
#  'Request: Is this an eating disorder?',
#  "Request: I don't know where to go from here",
#  'Request: Roommate potentially has an eating disorder -- need advice',
#  'Request: Questions about BED: Where do I start?',
#  'Request: Need advice from those who have experienced ED or loved ones who have experienced it',
#  'Request: I am a bit confused and would like some input.',
#  'Request: Trying to understand her after a break up, please help',
#  'Request: HELP. Medication (Paxil) weight gain triggering another relapse?',
#  'Request: How to help a friend',
#  "Request: I'm going to lose my job either way. Feeling hopeless.",
#  'Trying to avoid knowing my weight as part of recovery, until today. What the heck do I do now?',
#  'Request: Do I have an eating disorder?',
#  'Request: Renfrew In Philly',
#  'Request: Horribly trapped',
#  'Request: How to get over physical side effects of eating disorder?',
#  'Request: One toe still in ED?',
#  'Request: Supporting my girlfriend who refuses to see her ED as a problem',
#  'Request: Had an important photo taken and I look fat in it. How do I cope with this?',
#  "Request: How to deal with my mom's critical comments?",
#  'Request: Asking mom if we could have less "binge foods" in house',
#  "Request: I'm stuck! suggestions?",
#  "Request: I'm unsure what to do at this point.",
#  'Request: I feel alone and need advice',
#  'Request: How to fix lack of appetite?',
#  'Request: Do I have an eating disorder or am I making things up?',
#  'Request: I found out a classmate of mine has an eating disorder- what should I do?',
#  'Request: Need some perspective about possible eating disorder',
#  'Request: How long should I wait before working out again? (AN Recovery)',
#  'Request: Found out my girlfriend is anorexic, I want to help however I can',
#  'Request: I think my sister has an eating disorder',
#  'Request: How should I help my BN friend more?',
#  'Request: Weight is Stabilizing',
#  'Request: How do i stop?',
#  'Repost: Academic Research request for survey participants',
#  'Mobile app to supplement eating disorders treatment',
#  'Request: Sponsors?',
#  "Request: How will my girlfriend's behaviour change as she recovers?",
#  'Request: nightly binge eating syndrome',
#  'Request: Helping my friend who lives abroad',
#  "Request: How should I support an online friend with an ED whom I've never met in person",
#  'Request: Restrictive eating causing horrible anxiety. Need help',
#  'Request: Do I actually have an ED?',
#  'Request: Advice for a housemate',
#  'My friends think I have an eating disorder. Are they right to worry?',
#  'Request: Is going from severely underweight to overweight a common occurrence?',
#  "Request: Doctor said I have an eating disorder and I didn't know",
#  'Request: Eating issues',
#  'Request: Online forum where my mum can talk to other families caring for girls with eating disorders?',
#  'Research Participants Sought: Do you have an eating disorder or suspect you might have an eating disorder? Participate in our "closing the treatment gap" survey and we will donate $10 AUD to eating disorders charity',
#  "Request: Daughter's Friend has asked for our help",
#  'Request: Has anyone been treated at the Emily Program? What was it like?',
#  'Request: Recovering while also getting to a lower, healthy weight',
#  'Request: Doctors recommendation is making things worse?',
#  'Request: Should I tell my doctor?',
#  'Post request: [recovery] healthy intake',
#  'Request: Physiological Complications with Recovery',
#  "Request: How do I get over feeling like I don't deserve to eat?",
#  'Request: How to recover from an episode of binge eating?',
#  'Request: Do you think my student has an eating disorder?',
#  'Request: Binge Eating...how to stop a cycle',
#  'Request: Eating disorders as an athlete',
#  "Request: My girlfriend has had an ED for years, but hasn't told her new therapist. Should I say something?",
#  'Request: Do you think I should see a nutritionist or a psychologist?',
#  'Request: Need Some Input',
#  'Request: Need advice about ED coming back',
#  'Request: EDA vs OA',
#  'Post Request: What constitutes being in recovery?',
#  'Request: feeling sick when eating, help?',
#  'Request: Involuntary vomiting during bulimia recovery',
#  'Request: Restrictive Eating Recovery',
#  'Request: 50 days binge/purge free but I dont feel better',
#  '[ED Article] How to do Christmas better',
#  'Request: Girlfriend has an eating disorder but wants to work as a gym trainer.',
#  'Request: Christmas gift ideas for teenager currently hospitalized',
#  'Request: How to help my girlfriend recover',
#  'Request: Managing a career in geology with an ED',
#  'Request: Supporting SO with ED',
#  "Request: I suspect my elderly mother's live-in care-giver has an ED and I'm worried about my mom's health/safety",
#  'Requst: Is there a support group?',
#  'Request: How to handle medical leave gracefully?',
#  'Request: Request for help with BED',
#  'Request: ED Center is pushing for inpatient',
#  'Request: Information and advice for folks with NSRED',
#  'Request: Worried that my sister who struggles with bipolar disorder is purging. How do I proceed?',
#  "Request: Bulimic for 2 years and continuing and I don't know how to get help",
#  'What can I expect in inpatient treatment?',
#  'Request: Anxiety Induced Anorexia Problem with Dizziness/Slurred Speech',
#  'Request: Timberline Knolls',
#  'Request: How do I know where to draw the line?',
#  "Request: I'm underweight and don't know if I have an eating disorder",
#  'Request: Meal services that provide healthy meals (not for weight loss)',
#  'Survey: Quick eating disorder survey',
#  'Request: How to stay motivated for recovery?',
#  'Request: Girlfriend with ED wants to end our relationship',
#  'Request: How do I deal with outside voices, mostly family members?',
#  'Post Request: Binge Eating Disorder-help needed',
#  'Request: Need bulimia support/advice. Getting worse',
#  'Request: Stuck in a recovery-relapse cycle... what to do?',
#  'Request: I need advice about how to help my roommate with an ED',
#  'Request: A good therapist in Ft Collins, CO',
#  'Request: How to recover from eating disorder/dual depression',
#  'Request: Changed Taste Sensations or Odd Food Combinations',
#  'Request: How to help my girlfriend dealing with her own image',
#  'Request: Request for advice for helping college roommate',
#  'Request: How do I help my girflriend with her long-term ED?',
#  "Request: I don't know if I should still get help",
#  'Request: Recovery from Binge Eating',
#  'Request: How to eat? 3 Meals a day? At specific times?',
#  'Request: Are things getting worse?',
#  'Request: How do I get rid of or cope with the guilt?',
#  'Request: What is NORMAL eating? How do I include "bad foods"?',
#  'Request: accidental relapse?',
#  'Request: Menstruation Questions?',
#  'Request: Pregnant and disordered, how can I make healthy choices for myself and my baby? How can I deal with emotions and feel more stable?',
#  "Request: I don't know what's wrong with me",
#  'Request: I think my fiancee has an eating disorder. Long distance relationship.',
#  'Molecular Origins Of Eating Disorders Found In Gut Microbe',
#  'Request: Talking to my sister about her eating disorder.',
#  'Request: Just want to give up. Why recover?',
#  "What's New in Eating Disorders Treatment and Research?",
#  'Request: Do I suffer from an Eating Disorder ?',
#  'Request: Designing an Outpatient Facility- thesis research by someone in recovery from an eating disorder',
#  'Request: How to handle lunchtime with dieting colleagues and their talk, particularly comments to me?',
#  'Request: Crazy binge-purge relapse after 8 years of somewhat healthy life',
#  'Request: Help with short play script about a person with bulimia. TW',
#  'Request: Help editing a short script about a person with bulimia. TW',
#  'Request: Help editing a short script on a person with bulimia. TW',
#  'Request: Very concerned about a 7 year old.',
#  'REQUEST: Help talking to a teammate with a potential ED (TW!).',
#  'Request: How to tell my housemate I have bulimia?',
#  'Request: How did you accept the fact that you will gain body-fat during recovery?',
#  "Post Request- I'm spiraling into an eating disorder, family history of EDs, I don't know why my mood keeps going like this.",
#  'Request: Has anyone gotten pregnant while coping with ED? Can EDs effect the chances of having children?',
#  "Request: I think I need help, teen with bulimia, parents don't seem to know what to do.",
#  'Post request: How to differentiate between orthorexia and just wanting to be healthy? Healthy diet vs ED?',
#  'Request: Triggered after therapy',
#  'Request: What to do about sister',
#  'Request: My former boyfriend has left me because of my EDNOS - how do I cope?',
#  'Request: Is there such a thing as a full recovery?',
#  'Request: Is it counter intuitive to count calories in recovery?',
#  'Request: Binging in Recovery, hopelessness, social concerns about gaining weight',
#  "Request: Recovering bulimic dieting, don't want to slip into old habits.",
#  'rRequest: bulimia caused by poverty, food insecurity',
#  'Request: My will to not purge is failing. Need advice on how to turn away from bulimia',
#  'Request: Baby steps towards recovery. (Male, 20 yrs old), previously anorexia, now bulimia (non-vomiting)',
#  'Request: Recovery from AN b/p type, it seems like no one understands',
#  'Resistance to Treatment: Anosognosia and Eating Disorders',
#  'Request: Befriended and now falling for girl recovering from Anorexia. Advice?',
#  "Request: I don't know when to stop eating! Help??",
#  "Request: Just recently acknowledged I binge eat and don't even know where to begin..",
#  'Request: How to help bulimic girlfriend',
#  'Request: How to approach roommate who I believe is bulimic',
#  'Request: How to get help while studying abroad',
#  "Request: Sick of being like this and don't know what to do, binge eating",
#  'Request: How much can I lean on my boyfriend for help? Bulimia, binge / purge.',
#  "Request: Eating Disorder Triggered Due to Ex's Comments",
#  'Request: How do I talk to my husband about my eating disorder - food addiction?',
#  "Dangers of Eating Disorders Among Students: It's not just females, as there has been a 66 percent increase in the number of men hospitalized with such over the last decade. ",
#  'Post Request: Do my observations about my girlfriend warrant further concern? How do I approach her about this, if I do?',
#  'Eating Disorder Sufferers Face Long Waits for Treatment | CBC',
#  "Post request: I want to start getting fit, but I'm afraid of relapsing. Any advice?",
#  'Post request: Recently accepted that I have an eating disorder.  Not sure what to do about it.',
#  'How Do I Ask For Help?',
#  'Post Request: Help with what to eat.',
#  'Post request: Started out as an attempt at getting fit, severely relapsed. I need help.',
#  'Post Request: Sudden Relapse. What should I do?',
#  'Post Request: How can I keep it together when I feel like falling apart again?',
#  "Post Request: The scale isn't my friend. But, right now, I feel it's the closest thing I've got.",
#  'EDNOS: Deadliest Eating Disorder Is Quietly the Most Common - Yahoo!',
#  'Post Request: How to tell SO I have an ED and have relapsed lately?',
#  'Post request: I am in urgent need of advice on how to approach my 21 year old brother.',
#  'Post Request: Ready to finally get help, but any way to do so without involving parents?',
#  'Eating disorders often leave patients facing difficult insurance hurdles.',
#  'Getting Help',
#  'Post request: Someone told me I had an eating disorder, not really sure if I should believe him.',
#  "Post request: Struggling with an undiagnosed eating disorder and I don't know what to do.",
#  "Post request: I'm 24 years old and am scared I am developing an eating disorder. I have never experienced anything like this before and really would like some advice?",
#  'Petition for Seventeen Magazine\'s 14.8 BMI as "healthy" to be removed.',
#  'Post Request- How do you deal with triggering speak? ',
#  'Post Request: Best friend might be bulimic, adults decide it\'s a "teenage phase"..now I\'m confused. What can I do?',
#  'PostRequest: ED, EDNOS or just lazy? (possibly TR)',
#  'Post Request: Aged-out of insurance, really need help.',
#  'Post request: I suspect my boyfriend is bulimic. I really want to support him, but also struggle with self-injury and am not sure how best to handle his issues atop my own.',
#  "How do you change your mind when it's set?",
#  "How do you change your mind when it's set?",
#  'loosing faith in recovery',
#  'Request: Eating After an ED?',
#  "Request: I'm starting treatment for bulimia - what are some good resources for my husband?",
#  'Request: Request: Will my immune system ever return to normal?',
#  'Request: Do those little ED habits ever go away?',
#  'Request: Any advice for binge eating disorder (BED) recovery?',
#  'Request: Permanently burst blood vessels / bloodshot eyes from purging?',
#  'Request: Advice on losing weight after recovery',
#  'Request: Is Male Anorexia real?',
#  'Request: Girlfriend struggles with anorexia and I would like to help her',
#  'France Moves to Ban Ultrathin Fashion Models to protect models.',
#  'France Moves to Ban Underweight Fashion Models to protect the working models.',
#  'Request: Concerned Friend',
#  'Request: How To Not Worry About Calories',
#  'Request: Trying to understand how she thinks as far as her eating disorder!',
#  'REquest: Looking for advice for family member',
#  'Request: I need help with my binge eating disorder. Thoughts of self harm.',
#  'Request: Dealing with guilt over BED',
#  'Request: Realizing I have binge eating disorder - where to start looking for help?',
#  'Request: Bulimia bloat or weight gain?',
#  'Request: Overcame an eating disorder 6 years ago; still having side affects.',
#  'Anorexia nervosa: New research underlines importance of getting help before chronicity sets in -- ScienceDaily',
#  'Request: Advice for couple in recovery',
#  'Request: How to stop feeling guilty every time I eat?',
#  "Request: Not sure what my disorder would be qualified as and I feel like that's where I need to start.",
#  "Request: I don't know how to stop my bulimic episodes, I feel like I've lost power over my behaviors.",
#  'Request: Do I have Binge Eating Disorder?',
#  'Request: Do eating disorders need to be about body image?',
#  "We're looking for a few good moderators! If you have time, energy, and interest in helping others with Eating Disorders, consider applying!",
#  "We're looking for a few good moderators! If you have time, energy, and interest in helping others with Eating Disorders, consider applying!",
#  'Request: Worried about hair loss',
#  'Request: Am I Bulimic?',
#  'Request: Worried I might be developing an eating disorder',
#  'Request: Recovering bulimic - how to deal with weight gain from needed medication?',
#  'Scientists manage to give mice ‘eating disorders’ by knocking out one gene - Washington Post',
#  'Request: How to deal with triggers in inpatient treatment?',
#  'Request: How to help girlfriend who refuses treatment',
#  'Request: How can I support and talk to my good friend with anorexia?',
#  "Request: Girlfriend enters residential treatment then tells me she cheated on me and expects me to think that's okay. Why did she do this?",
#  "Request: Abstinence in OA versus no forbidden foods... I'm so confused!",
#  'Request: How can I help my cousin? I am worried she is developing an eating disorder.',
#  'Request: Scared that I might be developing an eating disorder',
#  'Request: Moving from the denial stage into the request for help stage...',
#  'Request: Has anyone developed an ED from Rape? How do control issues relate?',
#  'Overcoming an Eating Disorder With Instagram: Showing the hard work of getting better. - The Atlantic',
#  "Request: How can I help my girlfriend? I'm nervous she's developing an eating disorder.",
#  'Request: Worried about my friend-how can I help her get help?',
#  'Request: Type 1 Diabetic, help',
#  'Survey',
#  'Request: Girlfriend with esophageal rupture - how can I help her?',
#  'Request: How can I get better in a stressful environment?',
#  'Request: How do I get help? 16 and cycles of binging, restricting, shame, etc.',
#  "Request: 23 and I'm freaking out. Panicked, undereating, that leads to eating in my sleep.",
#  'Request: My friend is abusing laxatives. What are the risks?',
#  'Request: Detecting ED Behaviors in Partner',
#  'Request: Selective Eating Disorder/ Food Avoidance Disorder',
#  'Request: Feeling a need to relapse without official treatment-- I feel I won\'t get treatment until I "look" sick enough, how can I cope and deal?',
#  'Request: Bulimia behavioral questions about my girlfriend.',
#  'Request: My roommate might be relapsing into his ED...',
#  'Missouri Senate Endorses Eating Disorder Bill Requiring Insurance Companies to Cover the Diagnosis and Treatment of Eating Disorders.',
#  "Request: I struggle with body image and self-esteem, but I'm not sure if it's an eating disorder. What should I do?",
#  'Request: My girlfriend has EDNOS',
#  "Request: How do I get over the shame of having an eating disorder? How to deal with people making casual jokes about EDs when they don't know I've done the work to recover from one?",
#  'REquest: My girlfriend has an ED, bulimia. I want to be as supportive and sensitive as possible. What is it like being a partner to someone with an ED?',
#  'Request: Is my eating disorder shifting shapes or am I getting better?',
#  'Request: Seeing hot girls triggers me a lot',
#  'Request: Boyfriend likes my "chubby cheeks", he doesnt know it makes me feel fat',
#  'Request: Extreme fatigue on rest days, worried my eating is disordered',
#  'Request: concerned I may be headed toward an eating disorder',
#  'Questionable therapist approach to ED',
#  'Request: Helping a close friend with purging',
#  'Participants needed for mothers in Recovery from Eating disorders',
#  'Request: I am relapsing, nobody knows about my ED, I feel out of control. What now?',
#  'Request: Not sure if I had an eating disorder',
#  'Request: Has anyone ever told someone else about your eating disorder without your permission?',
#  'Request: Could this be a relapse?',
#  'Request: Experience with ED Rehabilitation Centers?',
#  '#I am not Ed - Eating Disorders Awareness Week campaign',
#  'Request: I lost a lot of weight from an ED and sometimes gain weight when still undereating, can my metabolism recover if my eating does?',
#  'Request: I started restricting and purging and it is getting worse due to intrusive thoughts. How do I get out of this cycle?',
#  'Follow up: First 24 hours without purging!',
#  'Request: ED or emotional anxst / overreacting?',
#  'Request: Books/resources for SO?',
#  "Request: Obsessive Thinking About What HE'S Eating",
#  'Request: Need immediate help for GF who is having a breakdown',
#  'Request: Do I have an eating disorder, anorexia, or just bad habits?',
#  "Request: Remembering that I'm a binge eater..",
#  'Equine Therapy for Eating Disorders',
#  'Request: Advice on helping girlfriend with EDNOS',
#  "Survey: Anonymous ED survey, Chance to share your story if you'd like",
#  'Started recovery and noticing pains in my body. What should I do?',
#  'Request: Think girl I am dating has an ED. If so, ow do I approach her about it?',
#  'Request: Request for advice on how to talk to roommate/best friend about recent habits?',
#  'Request: Quitting Calorie Counting/Exchanges/Measuring Food Cold Turkey...good idea? Ways to manage anxiety, intuitive eating, etc?',
#  'Request: Roommate concern, bulimia',
#  'Request: Vyvanse for BED/Binge Purge: Anyone With Experience?',
#  'Request: Anxiety, depression, bulimia, and saying the wrong thing to my ex, nipping BN before it gets worse.',
#  "Request: It's Getting Worse, thoughts of purging",
#  'Navigating Weight Loss After an Eating Disorder. -Not a perfect article, but a beginning.',
#  'Request: Does anyone work in the health field?',
#  'Request: help with an out of town friend',
#  'Request: How to stop the nosedive that my relapse is taking',
#  'Request: What are some steps that I can take to control my compulsion to B&amp;P?',
#  'Request: How to deal with a friend (long distance) who has bulimia/an eating disorder? How can I best relate to her difficulties?',
#  "Request: How do I know if it's a problem?",
#  "The Truth about Eating Disorders: one person's experience with not wanting to recover, then wanting to enjoy life more than have an ED.",
#  'Request: Online support for ENDOS? How to cope with being in a foreign country and needing help?',
#  'Request: Broken the bulimia cycle, but need help with anxiety!',
#  'Request: Recovering but constant anxiety. Is there a helpful way to overcome this anxiety? (bulimia)',
#  'Request: Bone Density Scan after Anorexia, nervous! :(',
#  'Request: What should I have done?',
#  'Request: Binge eating is ruining my post-bulimia life. First steps to help myself?',
#  'Request: Personal responses to being diagnosed with EDNOS.',
#  'Request: I\'m not sure how my recovery is going. Confused if I\'m "recovered" even though thoughts about food/health still consume me. I feel alone. (bulimia)',
#  'Request: Has anyone got any experience with overcoming "picky eating"? Selective eating disorder?',
#  'Request: Disordered eating kicks my ass every holiday season',
#  "Request: 14 y/o diagnosed with BN and I don't know what I am doing. Why change?",
#  'Request: Is this considered a problem?',
#  'Request: How do I make healthy, "normal" people understand?',
#  'Request: Dealing with "sick" clothes, gifts that are too small for me.',
#  'Request: Minnie Maud? How did it work for you?',
#  'Request: Do I need to get a doctor involved?',
#  'Request: Continuing Recovery Out of Inpatient',
#  'Request: Need help with binge eating disorder',
#  'The 13 Best Eating Disorder iPhone &amp; Android Apps of 2014',
#  "Request: I'm worried my eating habits are unhealthy but don't know how to fix it",
#  'Thanksgiving',
#  'Request: Should I be drinking coffee?',
#  'Request: Permanent Damage from Bulimia?',
#  'Request: What was it that made you want to get help?',
#  'Request: Falling back into bad patterns.... What should I do? Wanting to hear about others who have sought treatment.',
#  "Request: I think I may have an ED and I don't know what to do",
#  'Request: People always commenting on what I eat. Makes me too self conscious to eat in front of anyone.',
#  "When looking at the weighing scale, how do you get over the numbers being higher than you'd like?",
#  'Request: Please, someone help me build up the confidence to try new foods.',
#  '10 "Will Powers" for Improving Body Image from NEDA, National Eating Disorders Association',
#  'Request: At what point does it become an eating disorder?',
#  'Request: Breaking the cycle and getting on the right track...what worked for you?',
#  'Request: In it deep, see no way out. Pls help.',
#  'Request: Not Sure How to Proceed, On the Verge of an ED',
#  "Request: [Help] I don't think I have an average eating disorder, it might be SED- Selective Eating Disorder.",
#  'Request: Please Help Me AN, is it serious?',
#  'Request: How to Help My Fiancee',
#  'Request: Is this the start of something bad? Throwing up from guilt after eating.',
#  'Request: Advice on what to say/do when my GF criticises her body.',
#  'Request: Should I mention she could gain a few pounds?',
#  "Request: I don't know if I have an eating disorder.",
#  'Request: Who do you talk to?',
#  'Request:Changing Treatment Team',
#  'Request: Searching for help dealing with an eating disorder',
#  'Request: Suggestions for how be comfortable with my body at a healthy weight?',
#  'Request: Remuda Ranch treatment center in AZ',
#  'Request: Scared father',
#  'Request: Remuda Ranch?',
#  'Sharing: Some of my personal experince on how to be there for your loved one with an ED.',
#  "Request: Getting started... I have a problem. I don't know what it is.",
#  'Request: Leaving for college soon ... nervous about ED relapse',
#  'Request: Is it possible for an ED to spread to other parts of my life?',
#  'Request: "Recovered", but persistent thoughts. Any tips?',
#  'Request: Thoughts, when do the thoughts to restrict and overexercise just stop?',
#  'Request: Edema in recovery, how to make it easier?',
#  "Request: I feel stuck and I don't know what to do",
#  "Request: I know I have an eating disorder, but I don't know which",
#  "Request: I want to recover, but I'm scared",
#  "Request: What will treatment team's reaction to self harm be?",
#  'Request: How can I stop a long binge from carrying on?',
#  'Request: I need advice. GF refuses to believe her ED is a problem.',
#  'Request: Medication side effects and ED',
#  "Request: I want recovery, but I also don't?",
#  'The Many Faces of Eating Disorders: New York Photo Exhibit Showcases Recovery',
#  'Request: Am I (male) still bulimic, or is it just a bad habit at this point?',
#  'Request: Questions: Fear of being mentally healthy because it will mean weight gain.',
#  "Request: My therapist doesn't care that I have an eating disorder. What do I do?",
#  'Request: How do I deal with an unsupportive mother?',
#  'Request: How to deal with having BED?',
#  'Request: Is it possible to ever love my body?',
#  'Request: My sister is bulimic...what can I do to help?',
#  'Request: Recovering from EDNOS, I feel so anxious about "bad" foods, how do I overcome this?',
#  "Request: Having trouble determining when I'm actually hungry.",
#  'Request: How can I stop my behaviours stop interfering with the positive things I want to do for myself?',
#  'Request: I had AN, developed BED, possibly have body dysmorphia. Need help for self-recovery.',
#  'Request: I had AN, developed BED, possibly have body dysmorphia. Need help for self-recovery.',
#  "Request: Went out with a girl who told me she's suffered from an ED her entire life, looking for advice",
#  'Request: Sleep during and after recovery?',
#  'Request: Self Help Books Available for Free Online?',
#  'Request: Discharge Depression?',
#  'Request: What is there to talk about in therapy?',
#  'Request: Recovering sister ignoring our family',
#  "Request: Can't be recovered and exercise/diet?",
#  'Request: Is this bulimia?',
#  "Request: I think my little sister has started purging, I've been bulimic for 4 years. Mother isn't helpful. Help.",
#  'Request: Hoping to nip ED in the bud.',
#  "Request: My dad said something awful to me, I've been clean for three years",
#  "Coroner's Ruling Seen as a 'Seismic Shift' in how Eating Disorders are Addressed in Australia.",
#  'Request: How to overcome guilt from eating ?',
#  "Request: Thoughts on totally unrestricted recovery and 'binging'?",
#  'Request: Recovered a long time now, how do you keep a healthy mindset about fitness?',
#  'Request: Recovered a long time now, how do you keep a healthy mindset about fitness?',
#  'Request: Curious about Eating Disorder Anonymous meetings...',
#  'Request: How to help my friend',
#  'Request: Anxiety and binging, how can I control myself?',
#  "Request: Girlfriend says she wants to recover, doesn't follow health care providers' advice. Are there any things I can be doing to help or things I should be avoiding?",
#  'Request: Ditch the scale?',
#  "Request: I'm serious, when will the obsession end?",
#  "Request: I (20 m) think I'm crazy and I feel my weight/muscle gaining goal is not attainable, here's my story.",
#  'Request: Sucessfully recovered from bulimia. Side effects?',
#  'March Against Eating Disorders Sept. 30, 2014. Come together, raise awareness, and influence federal policy related to eating disorders.',
#  'Request: What kind of after effects have people who suffered from long term BN experienced?',
#  'Request: I hurt myself purging, I think i need to admit my problem',
#  'Request: Will I ever completely be free of anxiety eating around others?',
#  'Request: amenorrhea after ED',
#  "Request: I'm worried my friend may be bulimic. Am I jumping to conclusions?",
#  'Request: How Would They Help Me?',
#  'Post request: alternatives to Ensure',
#  'Request: Really Need Help, Battling Disorder for 4 Years. This is Last Resort',
#  'Request: New to dating someone with an eating disorder.',
#  'Request: How do you decide to recover?',
#  "Request: I'm a 22 year old male. I believe I have an eating disorder. I need help, please.",
#  'Request: Honesty in Therapy',
#  'Request: Is this just the beginning? Should I be worried this could turn into a full blown eating disorder?',
#  'Request: Residency Programs, what did you like and dislike?',
#  'Request: What to do when feeling unsupported?',
#  'Title: Struggling with recovery from purge type anorexia. Help.',
#  'Request: Friend with eating disorder, I think. What should I do?',
#  'Request: My bf accused me of having an ED. Do I? Am I just to close to see it?',
#  '10 Things Parents Wish Educators Knew about Eating Disorders',
#  'Request: Can people tell if there is something wrong early on?',
#  'Request: 25(m) not sure what to do possible eating disorder but ashamed',
#  'Request: Friend undereats, rather antisocial, how can I help him?',
#  'Request: Are there 24-hour hotlines for people with ED?',
#  'Request: My GF has ED (she admitted it), need help on how to support her',
#  'Request: Unhealthy thoughts about food again. Advice to not go there?',
#  'Request: In recovery, gaining weight. How did you deal?',
#  'Request: Depression leading to eating disorder. Any advice for this?',
#  'Request: When do your periods usually come back after recovering from anorexia?',
#  'Request: Friend with ED but no insurance and depression',
#  'Request: How do I help a close friend who has been binging/purging?',
#  "Request: College student seeking advice on eating behaviors. I don't think I can handle this by myself anymore.",
#  'Request: Thursday is my Birthday',
#  "Request: I'm terrified of recovery because I'm not underweight.",
#  'Request: Possible permanent stomach damage from bulimia?',
#  'Request: Long distance friend has AN, how do I support?',
#  'Request: Recovering but scared by disordered thoughts',
#  'Eating Disorders: The Brain’s Foul Trickery. How the brain fools some of us into eating too little — or too much.',
#  'Request: Selective Eating Disorder, what can I expect from therapy?',
#  'Survey: Binge Eating Survey, “Exploratory Analysis of a Clinical Functional Assessment for Binge Eating”, Western Michigan University.',
#  'Request: How can I (girlfriend with AN) best help or make things easier for my SO?',
#  'Request: am I developing an eating disorder? How can I stop these cycles?',
#  "Request: I Want My Mind Back, why can't I remember things easily anymore? Why don't my treatment staff care about diagnosis?",
#  "Post Request: Update and help for my sister's recovery.",
#  'Athlete Colin Jackson speaks about his previous eating disorder: “If I knew then what I know now, I might still have that world record!”',
#  'Article: Rethinking treatment goals--including Cognitive Behavioral Therapy, as well as Improved Quality of Life--Improves Results for Those with Persistent Anorexia. Study by U. of London, U. of Chicago, U. of Sydney.',
#  'Article: Rethinking Treatment Goals--including Cognitive Behavioral Therapy, as well as Improved Quality of Life--Improves Results for Those with Persistent Anorexia. Study by U. of London, U. of Chicago, U. of Sydney.',
#  "Post Request: Is it possible to have an ED if you're eating at maintenance?",
#  'Post Request: What programs/help would you like to see from Eating Disorder organizations?',
#  'Post Request: Worried about a friend.',
#  'Post Request: Invitation to participate in a research study',
#  'Post request: Strong desire to start exercising again.',
#  'Post Request: Article - I Think My Loved One Has an Eating Disorder — Now What?',
#  'Post Request: Getting help for a family member of a patient',
#  "Post Request: How to discourage my gf from binging/purging when I'm not around.",
#  "Post Request: We're doing better but we still feel like there's help to be found.",
#  'Post Request: Is it possible I have an ED? "Eating normal" for now, but constantly worry about food, weight, appearance, and living with low self-esteem.',
#  'Post Request: Seeking Advice on Helping Wife with Eating Disorder',
#  "Post Request: Boyfriend's statement triggered an old response.",
#  'Post Request: Terrified of going to college',
#  'Post Request: At what point should a person seek out therapy?',
#  'Post Request: How can I help my friend?',
#  'Post Request: Parents Make ED worse',
#  'Post Request: Previously "recovered" bulimic, relapsing because of jealousy. What should I do?',
#  "Post Request: I'm worried about my friend",
#  'Post Request: What can I do to end the urge to binge and purge?',
#  'Teen Eating Disorders Increase Suicide Risk',
#  'Post Request: Worried about eating habits',
#  'Eating Disorders and Teen Suicide Attempts: The risk of suicide is thought to be 57 times greater at every age for people with anorexia compared to the norm.',
#  'Coaches, Athletes and Eating Disorders: What We Can Learn from Oakland University',
#  'Selective Eating Disorder?',
#  'Helping dealing with girlfriend',
#  'Welp, I ate about 12,000 calories in one sitting yesterday.',
#  'Request: How did you first realise you had disordered thoughts/an ED?',
#  "Request: I think i'm developing an eating disorder rapidly (21/m/UK)",
#  'Request: I am underweight for my height and hate the feeling of being full.',
#  'Request: Do you have any lasting side effects from your ED?',
#  'Request: Have I crossed the tipping point from disordered eating into an eating disorder?',
#  'Request: Advice Needed - Bulimic Girfriend',
#  'Request: Post requesting information regarding binge drinking water',
#  'Request: Help shifting meals',
#  'Request: My eating problems',
#  'Request: What are the long term health effects of binge eating—besides weight gain?',
#  'Academic Study: Seeking participants for a study on self-injurious thoughts and behaviors',
#  'Request: Binge drinking water',
#  'Request: Do I have a binge eating disorder? History of problems',
#  'Request: Adult mushing food',
#  'Request: How do I help out my well-meaning, albeit uninformed grandmother?',
#  'Request: (19/M) Are any of you men suffering from an ED? Has gender affected your experience?',
#  'Request: Personal and confidential information - how to avoid changing from one ED to another',
#  'Request: How can i get treated and why is it so hard to get treatment?',
#  'Request: Experience with "Unrestricted Eating"',
#  "Request: I'm afraid if I'm not being super restrictive I'm going to gain weight.",
#  'Request: is this behavior an eating disorder? If so, what would it be called?',
#  "Request: Please can someone just listen to me? The cycle is starting again and I can't tell anyone.",
#  'Request: Unsure how to go about asking for help',
#  'Request: Recommendations for a book recommendation for my girlfriend',
#  'Request: Advice for talking to an adult family member about anorexia',
#  'Request: How can I better support her?',
#  "[Request] Past body image issues are much better now, but I can't seem to keep a healthy weight and can't afford more food. What can I do?",
#  "Request: Weird thing has been happening lately, and I'm worried it's bringing back some old behaviors",
#  'Request: struggling right now, looking for some support',
#  "Request: Others' expirience with therapy (BED)",
#  'Request: How can I help my older sister with her anorexia?',
#  "Request: I want to help, but not make her like like I'm helping",
#  'Request: experience at Timberline Knolls or Castlewood',
#  'Request: Consent and Anorexia',
#  'Request: Help with her',
#  'Survey Request: Seeking adults with current or past eating disorders for online survey for doctoral research',
#  'Request: found myself in a pickle and looking for help',
#  'Request: How do I help my girlfriend [21] increase calorie intake?',
#  'Survey on anorexia and gender',
#  'Request: Vyvanse and Binge Eating Disorder',
#  'Request: I think one of my customers may be bulimic. Is there anything I can do?',
#  'Request: Not sure what help I need (also Canadian)',
#  'Request: I feel helpless',
#  'Request: Just rejected from ED clinic, need advice on self help',
# ...
#  'Request: "Set Point" in intensive outpatient recovery',
#  "[Article on BED] 7 things you should know about this 'secret' eating disorder that's more common than anorexia",
#  '[Request]Best Residential Treatment Centers in USA',
#  '[Request] Are there any good resources for ED recovery WITHOUT insurance?',
#  '[Request]Being overweight while in recovery has me scared of relapse.',
#  '[Request] How to help my little sister',
#  "Request: I've just realised I have bulimia and I need help",
#  'Request: How to cope with unplanned weight gain?',
#  'Request: Doctoral student seeks participants for online study',
#  'Request: Feeling devastated after problems with my psychiatrist.',
#  'Request: Is it "okay" to eat the same thing every day in recovery?',
#  '[Request] How can I stop restrictive thinking and enjoy food without the impulse to exercise?',
#  'Request: Helping girlfriend with negative thoughts after eating',
#  'Request: Addressing roommate behaviors?',
#  'Request: Asking a question about lanugo in recovery',
#  'Request: How do I stop when I don’t want to stop?',
#  'Book Recommendation: This book is saving my life',
#  'Request: Am I developing/have bulimia?',
#  'Request: Body-Positive Exercise Motivation',
#  'Request: i would like some advice how to help girlfriend',
#  'Request: Relapsing/restricting while on vacation',
#  'Request: How to stop Bulimia',
#  'Request: Eating out',
#  'Request: Trying to be better but my body won’t let me.',
#  'Request: Relapse and trouble finding help',
#  'Request: How Do I Get My Team To Address The Elephant In The Room?',
#  'Request: Do I Have An Eating Disorder Or Is It Just Depression?',
#  'Request: wondering if it is possible to have a subconscious eating disorder',
#  "Request: I started smoking to lose weight, and I feel like that's a problem. Does this sound like an eating disorder?",
#  'Request: How do I accept weight gain?',
#  "Request: How to tell if it's an eating disorder or other physical ailment?",
#  'Request: tips on helping a friend in recovery?',
#  'Request: Recovery Finally',
#  'Request: I Feel Trapped By Selective Eating Disorder',
#  'Request: Can my heart fully recover?',
#  'Request: Not sure this qualifies as an eating disorder?',
#  'Request: My Mom Has An Eating Disorder, What Can I Do?',
#  'Request: How Can I Learn To Eat And Stop Looking At What Other People Are Having?',
#  'Request: Any Tips For When Boss Comments On Eating Habits?',
#  'Request: Off To The Doctors Tomorrow',
#  'Request: My Bestfriend Has Bulimia... What Is To Blame For The Heart Problems?',
#  'Request: Helping GF Through Recovery - Impact Of Social Media',
#  "Request: I Just Need People Who Know What I'm Goimg Though",
#  'Request: In Recovery After 8 Years Of Bulimia',
#  "Request: Food Is Ruling My Life And I Can No Longer Tell When I'm Hungry",
#  'Request: How can I help my friend (age 13) recover',
#  'Request: Seeking Help - Student With A History Of Two Eating Disorders',
#  'Request: Telling Loved Ones About The Disorders',
#  'Request: Did spiritual practice aided you in recovery?',
#  'Request: Is It An ED If I Am Just Never Hungry?',
#  'Request: Considering but unsure so I want some info',
#  'Request: Seeking advice about limiting/blocking food delivery apps on smart phones',
#  'Request: Relapse?',
#  'Request: Was This An ED?',
#  'Request: Recovery Advice',
#  'Request: girlfriend Is Going Through An ED Again And Idk What To Do...',
#  'Request: A Little Advice Needed.',
#  "Request: I Feel Like I'm About To Relapse, What Should I Do?",
#  'Request: 22 Year Old Male Seeking Advice',
#  'Request: unmotivated to eat in the evenings',
#  'Request: Problems With Nausea',
#  'Request: Help With Getting Back To Healthy',
#  'Request: Girl I’m Dating Struggles With ED. How Can I Support Her?',
#  'Request: Running',
#  'Request: Weight Restoration Program',
#  'Request: Frustrations Of The Moment',
#  "Request: I don't know what's happening.",
#  'Research Request: Body + Eating problems in Men',
#  'Request: Concerned I May Be Developing An Eating Disorder',
#  'Request: Diabullemia',
#  'Request: Diet Frustration',
#  'Request: I Finally Told A Therapist About My ED',
#  'Request: Help With A Student',
#  'Request: My Friend Has Been In Hospital - How Can I Be An Encouragement?',
#  'Request: Moving in soon with a dear friend with anorexia. Im dieting. How can I help?',
#  'Request: mental illness / schizophrenia / depression / self harm',
#  'Request: Help with my partner (30F)',
#  'Request: Flipping between eating issues and having none at all?',
#  'Request: Worried about a guy seeing me naked for the first time',
#  'Request: Resources for understanding bulimia',
#  'Request: ISO advice on weight gain &amp; building muscle.',
#  'Request: My Friend Has Been In Hospital - How Can I Be An Encouragement?',
#  'Seeking Help For the Moderation Team',
#  'Request: Some Good News To Post',
#  'Request: Wife Taking Dulcolax, Looking For Advice',
#  'Request: How To Tolerate Being Full??',
#  'Request: Project HEAL: Recruiting Recovered Mentors',
#  'Request: Could I possibly have an ED?',
#  'Request: How to Avoid Being Enticed Back to Anorexia?',
#  "Request: I Don't Know if I Have an Eating Disorder",
#  "Request: Don't know where to go for help",
#  'Request: Am I eating too little?',
#  'Request: Am I helping my girlfriend with this in a constructive, long-term way?',
#  'Request: First steps after anorexia diagnosis?',
#  'Request; Do I have an eating disorder?',
#  'Request: do I have eating problems?',
#  "Request: Fat to normal looking, still can't eat like a normal person",
#  "Request: I don't but do I...",
#  "Request: I have no appetite for food and it's ruining my health, please help.",
#  'Request: My sister downloaded a calorie counting app. Should I be worried?',
#  'Request: advice recovering',
#  'Request: advice on loss of appetite explained',
#  'Request: Thinking about going back to anorexia',
#  'Request: Are there any medications that can be taken to gain weight?',
#  'Request: Missing the old, but horrible days',
#  'Request: Back at my (supposed) set point weight after anorexia, but still binging?',
#  "PhD Research Help: studying people's interactions with the Tumblr pro-ana &amp; pro-mia communities",
#  'Video: BBC series on mental health awareness',
#  'Request: Seeking art/poetry/prose submissions for mental health project',
#  'Request: Where do I turn to for help? Permanent physical effects of binge eating disorder',
#  'Request: When will my hair grow back?',
#  'Request: what to say and not say to a new friend with an ED?',
#  "Request: In truth it seems I don't really care. What to do?",
#  'Request: self-help tools, books, workbooks, journals, videos?',
#  'Request: Extreme cyclical hunger and restriction',
#  'Request: I need to help my anorexic sister',
#  'Request: Borderline bulimia without actually puking?',
#  'Request: What do you call yourself after you have recovered from an ED?',
#  'Request: Sister is hurting herself, need help',
#  'Request: Need advice',
#  'Request: SO has a new round of ED. How do i stay emotionally balanced?',
#  'Request: Unsure if I should tell my friend who has an eating disorder about my feeling for her',
#  'Request: Ready to STOP',
#  'Request: Feeling really anxious after eating out with friends',
#  "Request: I feel like I'm going crazy",
#  'Request: Bulimic girlfriend pushed me away completely',
#  'Request: Advice on what to say to friend',
#  'Request: GF in recovery',
#  'Request: Advice for my potentially anorexic friend',
#  'Request: Advice on how to help my friend',
#  'Request: Am I "sick enough" to be considered anorexic?',
#  'Request: Looking for people willing to help with Undergraduate writing assignment',
#  'Request: Is there a term for this?',
#  'Request: My friend has anorexia, she doesnt want help, What can I do?',
#  'Request: How to feel valid seeking treatment at a "healthy weight"?',
#  'Request: Anorexic afraid of purging, obsessing between mealtimes',
#  'Request: partner w/ ED and divorce topic',
#  'Request: How did you find and maintain balance on eating &amp; life?How did you find and maintain balance on eating &amp; life?',
#  'Request: showers',
#  'Request: How can I tell people it’s not okay to joke about my eating disorder?',
#  'Research Request: Trainee clinical psychologist recruiting adults (18+) with type 1 diabetes living in the UK for an online research study',
#  'Request: Recovery - "Extreme Hunger" vs. "Fat Logic"',
#  'Request: Orthorexia - asking for help on behalf of my girlfriend',
#  'Request: Anyone out there with experience with avoidant/restrictive food intake disorder?',
#  'Subject:can you? Can you be overweight and anorexic?',
#  "Request: What should I do if I think I'm relapsing",
#  'Request: My gf is anorectic / EDNOS with binge eating',
#  "Request: I'm confused....",
#  'Request: My Girlfriend sent me a poem about Ana, She wont get help',
#  'Request: Weight redistribution throughout/after recovery',
#  'Request: Has anyone had experience with Overeaters Anonymous?',
#  'Request: I want to help my friend',
#  'Request: Does it get better?',
#  'Request: I’m ruining my life, my relationship and everything I’ve ever known',
#  "Request: It's not over",
#  'Request: Can’t shake that societal obsession with getting fit',
#  'Request: Advice to not fall back',
#  'Request: What are the small things I can do for my gf with ED?',
#  'Request: I feel like my roommate is dragging me down to old habits.',
#  'Request: Research Participation',
#  'Request: Trying to Find Affordable Eating Disorder Group Homes',
#  'Request: Think I may be recovering from an eating disorder but never diagnosed',
#  'Request: Stopping my Bulimia',
#  'Request: Bulimia relapse- do I tell my boyfriend/family or not?',
#  'Request: Me with my wife of 3.5 years: Our relationship strain',
#  'Request: Tips or the best way to combat dry mouth?',
#  'Request: My relationship is at an all time strain',
#  'Help to stop binging/purging',
#  'Why not hair too?',
#  'Need those with eating disorders to answer some questions - research project',
#  "It's not just about not eating.",
#  'Eating Disorders and Dual Diagnosis',
#  'Your Family Tree Can Reveal Your Risk for Eating Disorders',
#  'PTSD in Military Women Can Put Them at Risk For Eating Disorders And Addiction',
#  'I need help with impulse control',
#  "I can't take it anymore...",
#  "How do you tell your date you're battling anorexia?",
#  'Started again today',
#  'I think I might be anorexic.',
#  'Eating Disorders and the Media: OMGaga had Bulimia!',
#  'The exorcism of eating disorders: Breaking up is hard to do',
#  "Here's what happens after having an ED for over 30 years.",
#  'Need help approaching teen about possible eating disorder',
#  'Something good happened last night. [possibly triggering]',
#  'BED is ruining my life. ',
#  'BED is ruining my life. ',
#  "I'm a boston blogger looking for someone local who has an eating disorder",
#  'Anorexia &amp; prescription drug abuse',
#  'Why Eating Disorders are Particularly Harmful to Pregnant Women',
#  'Eating Disorders are not Just a Lifestyle Choice',
#  'National Eating Disorder Awareness Week 2012: February 26- March 3',
#  'National Eating Disorders Awareness Week: February 26- March 3 2012.',
#  'Question/Advice etc. on whether I may have an eating disorder.',
#  'Does anyone else feel like therapy is a waste of time?',
#  'Laxatives, anxiety and nagging obsession...help!',
#  "Woman's Perspective",
#  'Not sure if I can do this here, but needed to vent',
#  'I wish this sub-reddit was more active. ',
#  "Once I start, I can't stop. Help me.",
#  'Following bad news coverage Tumblr is banning all Pro-Eating Disorder blogs. ',
#  'Thighs',
#  'Spam Filter',
#  "How to Help a Friend That's Abroad?",
#  'Is Censorship really the answer?',
#  'Today is the beginning of National Eating Disorders Awareness Week. Does anybody have anything planned for it?',
#  'My sister is bulimic and unapproachable about it. Any advice on how to handle this/what I can do to help her?',
#  'someone, please help me out!!',
#  'My Middle-of-the-Night Problems',
#  "Hello. My friend has an eating disorder and I'd like to learn all I can to help her.",
#  'Anorexia May Contribute to Categorical Learning Deficiencies',
#  'EATING DISORDER AWARENESS WEEK---A SHOUT OUT IS GOOD, BUT A SCREAM IS SO MUCH BETTER!',
#  'Teens and eating disorders: National Eating Disorder Awareness Week (NEDA)',
#  'Candlelight vigil marks opening of new home for local eating disorder foundation',
#  'Suggested Books for EDs?',
#  'Post request: In what ways do you cope with societal pressure to be thin?',
#  'Twelve Ideas to Help People with Eating Disorders Negotiate the Holidays From NEDA',
#  'Post Request: Help with an untraditional ED.',
#  'Post Request: I think I may be on the verge of developing a binge ED. If so, I want to do everything I can do to stop it in its tracks now before it becomes a real problem',
#  'Post Request: Recovering and needing guidance. ',
#  'Post Request:  I just want to know if ANYONE ELSE out there feels as helpess as I do towards their suffering SO.',
#  "Post Request: What I'm\xa0trying to ask is how do I go from starving my body to feeding it properly without it going haywire on me and keeping everything as fat.",
#  'Post request: Struggling with bulimia and feeling hopeless.',
#  'Post Request: How can I ask my mom to eat unhealthy things with me?',
#  'Post request: Concern with my girlfriend who has a past of BN',
#  'Hunger Hormones: What They Are and Why We Need to Make Them Our Friends. ',
#  'Post Request: Anorexia athletica: am I reaching/imagining or is this a real problem?',
#  'Post Request: I need help. I think my gf is suffering from anorexia.',
#  'Nearly 1 million Australians Suffer from Eating Disorders such as anorexia, bulimia, obesity and binge-eating, new research shows.',
#  'Post Request: Stomach pains, emotionally volatile and crying almost daily, food in tolerances, binging, purging, restricting, tired of living this way.',
#  'Post request: Help coping with exercise and eating enough calories to justify?',
#  "Post Request: Worried something's really wrong with me",
#  "Post Request: Seventeen Year Old Guy. I'm really afraid. What can I do?",
#  'Eating Disorder Recovery During Holidays -- Popular myths about the magic of the holidays set many Americans up for a struggle with real life.  Certain strategies can help individuals protect their recovery.',
#  "Post request: I think my GF has bulimia.  Please help, I'm feeling desperate.",
#  'Post Request: Going through MAJOR relapsing while home for Christmas: I just need some advice on what to do for the next 4 days that I am home.',
#  "Post request: I have anorexia and I'm pregnant. Anyone else out there with an ED who has had children?",
#  " Post Request: How to help someone--who's 8 years old--with an eating disorder?",
#  'Post Request: Wait to see medical professional, or start to increase calories on my own?',
#  'Post Request: Wait to see medical professional, or start to increase calories on my own?',
#  'Post Request: GF is bulimic, I would like to hear some opinions of people who have been in similar situations and how they dealt with them. How can I help her without upsetting her further?',
#  "PostRequest: Chewing and spitting, occasionally bulimic, and I don't want to live like this. Please help.",
#  'Post request: There is hope.',
#  "Post Request: I have an unhealthy relationship with food and I'm desperately seeking help.",
#  'Post Request: Need some information, keep reading conflicting things. Also, "negative inside voice"',
#  "Post Request: I'm 100% sure I have Selective Eating Disorder. What to do? See my GP? A dietician? A nutritionist? Hypnotherapist?",
#  'Request: Uneasy about going to Overeaters Anon',
#  'Request: Need advice Hope this is the right place',
#  'Request: Relapsed. Again. Any advice?',
#  'Request: Do I have an eating disorder?',
#  'Request: Think I might have some sort of ED. What is body dysmorphia, and how do I overcome the fear of gaining weight?',
#  'Request: My mom has an eating disorder. What do I do?',
#  'Request: How can I tell if I need help?',
#  'Request: Experiences with U.S. FMLA or disability for inpatient treatment',
#  'Request: Help with nutrition class',
#  ...]

# %%
bayes_compare_language(mh_convos, e_convos)
# Out:
# Vocab size is 413
# Comparing language...
